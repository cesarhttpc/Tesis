# %% [markdown]
# # Plotly

# %%
# ! pip install plotly==4.4.0
import plotly.express as px

# %% [markdown]
# ### Gráfico de puntos

# %%
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species")
fig.show()

# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species",
                 size='petal_length', hover_data=['petal_width'])
fig.show()

# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
fig.show()

# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species", marginal_y="histogram",
           marginal_x="histogram", trendline="ols", template="simple_white")
fig.show()

# %% [markdown]
# ### Histograma

# %%
import plotly.express as px
df = px.data.iris()
fig = px.histogram(df, x="sepal_width", y="sepal_length", color="species",
           marginal="box")
fig.show()

# %%
import plotly.express as px
df = px.data.iris()
fig = px.histogram(df, x="sepal_width", y="sepal_length", color="species",
           marginal="box", barmode='overlay')
fig.show()

# %%
import plotly.express as px
df = px.data.iris()
fig = px.histogram(df, x="sepal_width", y="sepal_length", color="species",
           marginal="box", barmode='group')
fig.show()

# %%
import plotly.express as px
df = px.data.iris()
fig = px.histogram(df, x="sepal_width", y="sepal_length", color="species",
           facet_row="species")
fig.show()

# %%
df = px.data.iris()
fig = px.density_heatmap(
    df,
    x="sepal_width",
    y="sepal_length",
    nbinsx=20,
    nbinsy=20,
    histfunc="count",  # or "sum", "avg", "min", "max"
    marginal_x="rug",
    marginal_y="histogram",
)
fig.show()

# %%
fig = px.density_heatmap(
    df,
    x="sepal_width",
    y="sepal_length",
    facet_row="species",
)
fig.show()

# %% [markdown]
# ### Diagrama de barras

# %%
import plotly.express as px
df = px.data.tips()
fig = px.bar(df, x="sex", y="total_bill", color="smoker", barmode="group")
fig.show()

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#aggregate sum by first 2 levels
df_bill = df[['total_bill','sex','smoker']]
df1 = df_bill.groupby(["sex", "smoker"]).sum()
df1
# Out:
#                total_bill
# sex    smoker
# Female No          977.68
#        Yes         593.27
# Male   No         1919.75
#        Yes        1337.07

# %%
df2 = df_bill.groupby(["sex", "smoker"]).count()
df2
# Out:
#                total_bill
# sex    smoker
# Female No              54
#        Yes             33
# Male   No              97
#        Yes             60

# %%
import plotly.express as px
df = px.data.tips()
fig = px.box(df, x="sex", y="total_bill", color="smoker")
fig.show()

# %%
import plotly.express as px
df = px.data.tips()
fig = px.histogram(df, x="total_bill", color="sex")
fig.show()

# %%
import plotly.express as px
df = px.data.tips()
fig = px.bar(df, x="sex", y="tip",  color="total_bill", barmode="group")
fig.show()

# %%
import pandas as pd
df['tip_cat'] = pd.cut(df['tip'], bins=3, labels=['Poca', 'Media', 'Alta'])
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size tip_cat
# 0       16.99  1.01  Female     No  Sun  Dinner     2    Poca
# 1       10.34  1.66    Male     No  Sun  Dinner     3    Poca
# 2       21.01  3.50    Male     No  Sun  Dinner     3    Poca
# 3       23.68  3.31    Male     No  Sun  Dinner     2    Poca
# 4       24.59  3.61  Female     No  Sun  Dinner     4    Poca
# 5       25.29  4.71    Male     No  Sun  Dinner     4   Media
# 6        8.77  2.00    Male     No  Sun  Dinner     2    Poca
# 7       26.88  3.12    Male     No  Sun  Dinner     4    Poca
# 8       15.04  1.96    Male     No  Sun  Dinner     2    Poca
# 9       14.78  3.23    Male     No  Sun  Dinner     2    Poca

# %%
import plotly.express as px
df = px.data.tips()
df['tip_cat'] = pd.cut(df['tip'], bins=3, labels=['Poca', 'Media', 'Alta'])

fig = px.box(df, x="sex", y="total_bill", color="smoker",facet_col='tip_cat' )
fig.show()

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size tip_cat
# 0       16.99  1.01  Female     No  Sun  Dinner     2    Poca
# 1       10.34  1.66    Male     No  Sun  Dinner     3    Poca

# %% [markdown]
# ### Diagrama de embudo

# %%
import plotly.express as px
data = dict(
    number=[39, 27.4, 20.6, 11, 2],
    stage=["Website visit", "Downloads", "Potential customers", "Requested price", "invoice sent"])
fig = px.funnel(data, x='number', y='stage')
fig.show()

# %% [markdown]
# ### Diagrame de pie concatenado

# %%
import plotly.express as px
df = px.data.tips()
fig = px.pie(df, values='total_bill', names='day')
fig.show()

# %%
import plotly.express as px
df = px.data.tips()
fig = px.sunburst(df, path=['sex', 'day', 'time'], values='total_bill', color='time')
fig.show()

# %%
import plotly.express as px
import numpy as np
# load data from builtin Plotly data
df = px.data.gapminder()
# prepare a sunburst figure
fig = px.sunburst(df, path=['continent', 'country', 'year'], values='pop',
                color='lifeExp', hover_data=['iso_alpha'],
                color_continuous_scale='twilight',
                color_continuous_midpoint=np.average(df['lifeExp'], weights=df['pop']))
fig.show()

# %% [markdown]
# ### Diagrama (Treemap)

# %%
import plotly.express as px
df = px.data.tips()
fig = px.treemap(df, path=['day', 'time', 'sex','smoker'], values='total_bill')
fig.update_traces(root_color="lightgrey")
fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))
fig.show()

# %% [markdown]
# ### Diagrama 3D puntos

# %%
df = px.data.iris()
fig = px.scatter_3d(df, x='sepal_length', y='sepal_width', z='petal_width',
              color='petal_length', size='petal_length', size_max=15,
              symbol='species', opacity=0.7)

# tight layout
fig.update_layout(margin=dict(l=0, r=0, b=0, t=0))

# %% [markdown]
# ### Matriz de diagrama de puntos

# %%
df = px.data.iris()
fig = px.scatter_matrix(df,
    dimensions=["sepal_width", "sepal_length", "petal_width", "petal_length"],
    color="species", symbol='species')
fig.show()

# %% [markdown]
# ### Diagrama de lineas

# %%
df = px.data.iris()
fig = px.parallel_coordinates(df, color="species_id", labels={"species_id": "Species",
                "sepal_width": "Sepal Width", "sepal_length": "Sepal Length",
                "petal_width": "Petal Width", "petal_length": "Petal Length", },
                             color_continuous_scale=px.colors.diverging.Tealrose,
                             color_continuous_midpoint=2)
fig.show()

# %% [markdown]
# ### Diagrama Polar para datos circulares

# %%
df = px.data.wind()
fig = px.scatter_polar(df, r="frequency", theta="direction",
                       color="strength", symbol="strength", size="frequency",
                       color_discrete_sequence=px.colors.sequential.Plasma_r)
fig.show()

# %%
df.head(10)
# Out:
#   direction strength  frequency
# 0         N      0-1        0.5
# 1       NNE      0-1        0.6
# 2        NE      0-1        0.5
# 3       ENE      0-1        0.4
# 4         E      0-1        0.4
# 5       ESE      0-1        0.3
# 6        SE      0-1        0.4
# 7       SSE      0-1        0.4
# 8         S      0-1        0.6
# 9       SSW      0-1        0.4

# %% [markdown]
# ### Mapa

# %%
# load built-in gapminder dataset from plotly
gapminder = px.data.gapminder()

# create a map using choropleth
fig = px.choropleth(gapminder, locations='iso_alpha', color='lifeExp', hover_name='country',
                    animation_frame='year', color_continuous_scale=px.colors.sequential.Plasma, projection='natural earth')
fig.show()

# %%
# examine first few rows
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
gapminder['continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
# Load the dataset
data = px.data.gapminder().query("continent == 'Americas' & year == 2007")

# Create a Choropleth Map
fig = px.choropleth(data_frame=data,
                    locations='iso_alpha',
                    color='pop',
                    hover_name='country',
                    title='Urban Population',
                    color_continuous_scale='blues')

# Set the map layout
fig.update_geos(
    visible=False,
    resolution=50,
    showcountries=True,
    countrycolor="gray",
    showcoastlines=True,
    coastlinecolor="white",
    projection_type="orthographic",  #"natural earth",
    lataxis_range=[10, 40],
    lonaxis_range=[-90, -100]
)

# Display the map
fig.show()

# %%
data.head()
# Out:
#        country continent  year  lifeExp        pop     gdpPercap iso_alpha  \
# 59   Argentina  Americas  2007   75.320   40301927  12779.379640       ARG
# 143    Bolivia  Americas  2007   65.554    9119152   3822.137084       BOL
# 179     Brazil  Americas  2007   72.390  190010647   9065.800825       BRA
# 251     Canada  Americas  2007   80.653   33390141  36319.235010       CAN
# 287      Chile  Americas  2007   78.553   16284741  13171.638850       CHL
#
#      iso_num
# 59        32
# 143       68
# 179       76
# 251      124
# 287      152

# %% [markdown]
# ### Lineas

# %%
import plotly.express as px
data = px.data.gapminder().query("continent == 'Americas'")
fig = px.line(data, x='year', y='lifeExp', color='country')
fig.show()
